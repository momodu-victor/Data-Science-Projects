# %% [markdown]
# <h2><center>Predicting the out-of-state total cost for US public and private universities and colleges.</center></h2>
# <h2><center>Victor Momodu</center></h2>

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# ### Introduction/ Background of Study

# %% [markdown]
# The US is characterized to be one of the intellectual factories of the 21st century as it has more than 5,300 colleges and universities. As the cost of university education in the USA increases every year, it is important for students to understand what this implies when deciding on their "dream school." Although various factors should be considered when choosing a university, such as academic reputation and distance from home, "cost" should be strongly evaluated as it is dependent on the state the student lives in. There is often a significant price difference when comparing private and public universities as well as students that are residents of the state vs. those who live in a different state. The present project aims to provide prospective university students with data that will enable them to evaluate the cost of university attendance by predicting the out of state total which many times can be financed or defrayed depending on the state the student comes from. Nonetheless, first it is important to understand the context in which we will be analyzing the research question.
#
#
#
# Firstly, we should understand what is the difference between an in-state and out-of-state student. The US education system is controlled directly by each individual state rather than by the federal government. The public institutions within the state are financed by the taxes the state residents pay. As a consequence, state residents can attend these public schools for a lower cost, often referred as "in-state tuition", than those who do not live in the state that pay "out-of-state tuition." For the 2010–2011 academic year, the average tuition for an in-state student at a four year public school for an undergraduate student was \\$ 6,752. The average tuition for an out-of-state student at a four year public school for an undergraduate student was \$ 15,742. This means that, on average, it cost \\$8,990 more for students to attend a college or university in a state where they are not a resident (National Center for Education Statistics, 2013).
#
#
#
#
# Due to the significant price difference between in-state and out-of-state students, some states tend to be more stringent with regards to who qualifies to in-state tuition. For example, the policy on in-state tuition for the State University System of Maryland requires that a student have lived in the state for at least one year, did not move to the state solely to attend college, make Maryland their permanent residence indefinitely, and completely abandon the student’s previous home state (Heath Resource Center at the National Youth Transitions Center, n.d.).  Yet, students may have the opportunity of applying for reciprocity programs that are agreements between states that reduce the cost of university attendance for out-of-state students by limiting the out-of-state tuition rate to 150% of the in-state tuition rate. As a student, you have to be aware that these reciprocity programs are competitive as they have a limited number of open positions. Use the following report to inform yourself on the cost of attendance per university so that you are able to apply early and take advantage of the cost savings!
#
#
#
#
# Source: https://www.heath.gwu.edu/state-vs-out-state-tuition
#
# National Center for Education Statistics. (2013). Search for schools, colleges, and libraries. Washington, DC: U.S. Department of Education Institute of Education Sciences. Retrieved from http://nces.ed.gov/globallocator/

# %% [markdown]
# ### Purpose of Study.
#
# Most prospective students and their respective guardians oftern have questions that revolve around the following:
#
# * How much will it cost?
#
# * How much do we save?
#
# These are the most critical challenges in higher education planning.
#
# According to The College Board’s Trends in College Pricing 2018, the average annual cost of out-state tuition, fees, room, and board at a four-year public institution is \\$25,370 for the academic year 2018–2019. For a private institution, the cost of tuition, fees, room, and board is \$ 48,510. Both public and private colleges and universities experienced an increase of nearly 3% (2.8% for public and 3.2% for private) from the prior year, 2017–2018. Although the average tuition increase at private four-year schools is 3.3%, many students in this sector attend institutions with tuition increases of between 3% and 6%.If the cost of a college education increases by 6% annually, and your child enters a private college in the 2035–2036 academic year, the estimated tuition could be \\$57,544.
#
# For young families, skyrocketing cost projections can lead to sticker shock, but there are strategies that can help you keep pace with tuition hikes
#
# This project would help  estimate the approximate annual out_of_state_total cost for a two or four-year undergraduate education for either a choice for  public or private institution.
#
# Hence, using the US education data, we are offering a solution by **predicting the out-of-state total cost for public and private universities and colleges**.
#
# This would facilitate data-driven decision making for the prospective student and improve planning and budgeting.

# %% [markdown]
# ### Methodology
#
#
# **a.	Business Understanding:**
# * Determining what the cost would be for higher education is one of the most critical challenges in the educational system. Hence,using the US education data,we want to predictthe cost of the out_of_state total cost would be as this would improve planning and budgeting for propsective students.
#
# **b.	Data Retrieval:**
# The data used for this project was retrieved in a csv format consisting the latest records of US education data for public and private universities and colleges.
#
# This universities data set contains several higher education parameters.
#
# **Attribute Information:**
#
#
# **name**: The name of the university.
#
# **total_enrollment**: Total number of students enrolled.
#
# **state**: the state where the university is situated.
#
# **n_native**: Number of students that are natives.
#
# **n_asian**: Number of students that are asian.
#
# **n_black**: Number of students that are black.
#
# **n_hispanic**: Number of students that are hispanic.
#
# **n_pacific**: Number of students that are pacifics.
#
# **n_nonresident**: Number of students that are are not legal residents in the state where the university situated.
#
# **n_total_minority**: Number of students that are minority.
#
# **n_multiracial**: Number of students that are multiracial.
#
# **n_unknown**: Number of students that are their demographic is unknown
#
# **n_white**: Number of students that are white
#
# **n_women**: Number of students that are women.
#
# **state_code**: Unique state code for US states.
#
# **type**: Type of university either public, private, for profit
#
# **degree_length**: The duration of the course of study.
#
# **room_and_board**: This is usually the accomodation and rent cost.
#
# **in_state_tuition**: Tuition paid by students who are residents of state where the university situated.
#
# **in_state_total**: This is the total cost for students who are legal residents in the state. It consist of the in_state tuition + room and board
#
# **out_of_state_tuition**: Tuition paid by students who are non-residents of state where the university situated.
#
# **out_of_state_total**: This is the total cost for students who are not legal residents in the state. It consist of the out_of_state tuition + room and board
#
# **early_career_pay**: This is the average income a student who graduates from the university earns in the early years of career. This is usualy 1-2 years post graduation.
#
# **mid_career_pay**: This is the average income a student who graduates from the university earns in the mid years of career. This is usualy 3-6 years post graduation.
#
# **make_world_better_percent**: This is the percentage of the students who believe are making the world better.
#
# **stem_percent**: This is the percentage of the students who studied STEM related programs.
#
#
# Also, to build a robust predictive model, also used some other dataset in this project.
#
# * tuition_income data: This gives information on the total price, net cost, income level of all enrolled students for each university in the US.
#
# * Also, the Human development index (HDI) for each US state was used in the project.
#
#
# **Sources**:
#
# * https://elearning.jacobs-university.de/pluginfile.php/52758/mod_assign/introattachment/0/universities.csv?forcedownload=1
#
# * https://elearning.jacobs-university.de/pluginfile.php/52758/mod_assign/introattachment/0/tuition_income.csv?forcedownload=1
#
# * https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_Human_Development_Index
#
#
#
# **c.	Data Cleaning:**
# * As a next step, this project will evaluate the missing values within the data set to better understand how to deal with them. First, we search for patterns within the variables through visual inspection. There, we speculate how the distribution of the missing values would look like if they were available by discussing if the missing data is “missing completely at random”, “missing at random” or “not missing at random.” Also data types are checked, to ensure that accuracy in the analysis. Before doing the analysis and prediction, the data is checked if it is normalized. Furthermore, it is ensured that all column names are well described.
#
#
# **d.	Data Exploration:**
# * From the data set we explore basic questions to have a better understanding of the data. For example,which demographic characteristics are more pronounced for more expensive universities? How does the number of students from a particular region affect the total enrollement in states. Which groups are attracted to more expensive universities and so on.
#
#
# **e.	Data Visualization:**
#
# * Several plots and charts are used to further understand the relationships between the features and out of state total cost.
#
#
# **f.	Feature Engineering/Selection:**
# The following new features were included in the data set for better prediction of the out_of_state total
#
# * **n_men**: This is the number of enrolled students that are men.
#
# * **n_stem**: This is the number of enrolled students who studied a STEM programs.
#
# * **n_make_world_better**: This is the number of enrolled students who studied programs they believe make the world better.
#
# * **avg_net_cost**: The average total cost a student pays and subtracts any possible scholarships for which the student may receive.
#
# * **avg_total_price**: This average total cost of the universities over the years.
#
# * **HDI**: The Human Development Index of each state.
#
#
#
# **g.	Predictive Modelling:**
# * At this point, we use a regression model to predict the possible out of state total cost.
#
# * Every year, the  model can be run and it helps prospective student determine the out of state total cost.
#
#
#
# **h.	Data-Driven Insights:**
#
# * From the analysis, we gave data-driven insights and recommendation to prospective students as it relates to planning and budgeting the out-of-state cost.

# %% [markdown]
# ### Key Findings and Insight
#
# * There is total of 425 unversities in the top 10 US states by HDI. Out of which 211 are private, 197 are public and 17 are for profit.
#
#
# * Most universities enrolled less than 10,000 students.
#
#
# * Most universities enrolled less than 100 native students.
#
#
# * Most universities enrolled less than 50 asian students. However,some universities above 1000 asian students that were enrolled.
#
#
# * Most room and board cost between 12,000 and 16,000 dollars.
#
#
# * Most students earn between 45,000 and 58,000 dollars in their early career.
#
#
# * Less than 25% of students studied STEM related program at the university.
#
#
# * Most natives attend less expensive universities.
#
#
# * Non resident students attend the most expensive universities which could be private for profit universties.
#
#
# * The number of women being enrolled in the universities is increasing.
#
#
# * White students are kind of evenly distributed in the type of universties they attend in terms of cost. A good number go to expensive as well as less expensive schools.
#
#
# * The out_of_state_tuition is the most relevant to determine the out_of_total cost.
#
#
# * All cost variables (in_state_tuition, in_state_tuition total,average total price, average net cost, room and board ) important in predicting the out_of_state total.
#
#
# * The number of non_residents students in the universities play a key role in predicting the out_of_state total.

# %% [markdown]
# ### Recommendations based on the insights
#
# * Start a disciplined savings plan now from the results of the prediction. It will  better positioned to meet future education needs.
#
#
# * Ensure that the school you plan on attending is one that your financial pockets can afford as you have ample time to plan since the expected out of total cost has been forecasted.
#
#
# * Women could apply to less expensive universities as there is a high admission rate for the femine gender. Possibly applying to STEM courses could be a good option.

# %% [markdown]
# #### Import required libraries

# %%
#Import all libraries used in Analysis
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt #visualization 
import seaborn as sns

import plotly.offline as pyo 
import plotly.graph_objs as go
import plotly.figure_factory as ff
import math


import datetime as dt
import squarify
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

from scipy.stats import norm
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from scipy import stats
from sklearn.manifold import TSNE

# %%
from pandas import DataFrame
from scipy.stats import loguniform
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV, GridSearchCV, RepeatedKFold, RandomizedSearchCV
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor, plot_tree
# from sklearn.neural_network import MLPRegressor
from sklearn import metrics
# %matplotlib inline

# %% [markdown]
# ## Problem 1

# %% [markdown]
# #### Load the universities and tuition_income datasets.

# %%
data_uni = pd.read_csv(r"C:\Users\VICTOR\Downloads\DA_Final_Exam\universities.csv")
data_tuition = pd.read_csv(r"C:\Users\VICTOR\Downloads\DA_Final_Exam\tuition_income.csv")

# %% [markdown]
# #### Check structure of the datasets to ensure all variables are included

# %%
data_uni.head()
# Out:
#    Unnamed: 0                                  name  total_enrollment  \
# 0           0                Aaniiih Nakoda College               291
# 1           1          Abilene Christian University              4427
# 2           2  Abraham Baldwin Agricultural College              3458
# 3           3                       Academy College               127
# 4           4             Academy of Art University             15212
#
#         state  n_native  n_asian  n_black  n_hispanic  n_pacific  \
# 0     Montana       256        0        0           2          0
# 1       Texas        18       46      387         582          0
# 2     Georgia         9       36      407         197          1
# 3   Minnesota         1       10       14           6          3
# 4  California        70     1092      999        1383         75
#
#    n_nonresident  ...  degree_length  room_and_board  in_state_tuition  \
# 0              0  ...         2 Year             NaN              2380
# ...

# %%
# Drop the first column of the universities dataset
data_uni = data_uni.iloc[: , 1:]

# %%
data_tuition.head()
# Out:
#                                 name state  total_price  year     campus  \
# 0  Piedmont International University    NC        20174  2016  On Campus
# 1  Piedmont International University    NC        20174  2016  On Campus
# 2  Piedmont International University    NC        20174  2016  On Campus
# 3  Piedmont International University    NC        20174  2016  On Campus
# 4  Piedmont International University    NC        20514  2017  On Campus
#
#       net_cost         income_lvl
# 0  11475.00000        0 to 30,000
# 1  11451.00000   30,001 to 48,000
# 2  16229.00000   48_001 to 75,000
# 3  15592.00000  75,001 to 110,000
# 4  11668.39249        0 to 30,000

# %%
data_tuition.dtypes
# Out:
# name            object
# state           object
# total_price      int64
# year             int64
# campus          object
# net_cost       float64
# income_lvl      object
# dtype: object

# %% [markdown]
# #### Select from the universities dataset data for all universities located in the following states: Massachussets, Connecticut, Minnesota, New Jersey, New Hampshire, Colorado, North Dakota, Washington, Hawaii, New York.

# %%
# Create restricted data by select universities from these respective states.
uni_states = ['Massachusetts', 'Connecticut','Minnesota','New Jersey','New Hampshire','Colorado',
              'North Dakota','Washington','Hawaii','New York'] 
univ_data = data_uni[data_uni['state'].isin(uni_states)]
univ_data.head()
# Out:
#                             name  total_enrollment      state  n_native  \
# 3                Academy College               127  Minnesota         1
# 5         Adams State University              3154   Colorado        37
# 6             Adelphi University              7610   New York        10
# 7   Adirondack Community College              4247   New York        18
# 12        Aims Community College              5001   Colorado        33
#
#     n_asian  n_black  n_hispanic  n_pacific  n_nonresident  n_total_minority  \
# 3        10       14           6          3              0                35
# 5        37      191         812         10              0              1213
# 6       554      857        1007          6            436              2587
# 7        38      126         135          2              9               395
# 12       63       78        1631          9              4              1911
#
# ...

# %% [markdown]
# #### Check the distinct states of the filtered dataframe "univ_data"

# %%
# Get the unique values of 'state'
univ_data.state.unique()
# Out:
# array(['Minnesota', 'Colorado', 'New York', 'Connecticut',
#        'Massachusetts', 'New Jersey', 'Washington', 'North Dakota',
#        'Hawaii', 'New Hampshire'], dtype=object)

# %%
# # Check missing Values
# pd.DataFrame(univ_data.isnull().sum())

# %% [markdown]
# Next, we answer the following questions with the data

# %% [markdown]
# #### 1. How many universities are in the resulting dataset?

# %%
# How many universities are in the resulting dataset? 425
univ_data['name'].count()
# Out:
# 425

# %% [markdown]
# From the resulting dataset, there is a total of 425 universities. However, we notice **Middlesex Community College** appearing twice in the dataset.

# %%
univ_data['name'].value_counts()
# Out:
# Middlesex Community College               2
# Plymouth State University                 1
# Syracuse University                       1
# Metropolitan State University             1
# Colorado College                          1
#                                          ..
# Jewish Theological Seminary of America    1
# Hawaii Pacific University                 1
# Mohawk Valley Community College           1
# Great Bay Community College               1
# Hobart and William Smith Colleges         1
# Name: name, Length: 424, dtype: int64

# %%
uni_names = ['Middlesex Community College'] 
univ_data[univ_data['name'].isin(uni_names)]
# Out:
#                              name  total_enrollment          state  n_native  \
# 1127  Middlesex Community College              9205  Massachusetts        21
# 1128  Middlesex Community College              9205  Massachusetts        21
#
#       n_asian  n_black  n_hispanic  n_pacific  n_nonresident  \
# 1127     1051      663        1611          6            131
# 1128     1051      663        1611          6            131
#
#       n_total_minority  ...  degree_length  room_and_board  in_state_tuition  \
# 1127              3532  ...         2 Year             NaN              4404
# 1128              3532  ...         2 Year             NaN              6450
#
#       in_state_total out_of_state_tuition out_of_state_total early_career_pay  \
# 1127            4404                13172              13172              NaN
# 1128            6450                12630              12630              NaN
#
#       mid_career_pay  make_world_better_percent  stem_percent
# ...

# %% [markdown]
# It can be assumed that these two records of **Middlesex Community College** represent the two respective campuses in the state of Massachusetts which is one in **Lowell** and the other in **Bedford**.
#
# Source: https://en.wikipedia.org/wiki/Middlesex_Community_College_(Massachusetts)

# %% [markdown]
# #### 2. Graduates of how many universities have an estimated early career pay greater than 60000 dollars per year?

# %%
univ_data.query('early_career_pay > 60000')['early_career_pay'].agg(['count'])
# Out:
# count    33
# Name: early_career_pay, dtype: int64

# %% [markdown]
# From the data, **33** universities have an estimated early career pay greater than 60000 dollars per year.

# %% [markdown]
# #### 3. How many universities are not public?

# %%
# First we check the count of universities by type
univ_data['type'].value_counts()
# Out:
# Private       211
# Public        197
# For Profit     17
# Name: type, dtype: int64

# %%
# Count of universities that are not public
uni_type = ['Private', 'For Profit'] 
uni_notpublic = univ_data[univ_data['type'].isin(uni_type)]
uni_notpublic['name'].count()
# Out:
# 228

# %% [markdown]
# From the data, **228** universities are not public.

# %% [markdown]
# ## Problem 2: Making sense of your data

# %% [markdown]
# ### 1. Take a quick look at the data structure. Describe the dataset in a few sentences.
#
# * The dataset contains the admission information for universities and their respective enrolled students in the United States.
#
#
# * It contains data which describes the distribution of enrolled students with several criteria:
#
#     * **Race**: The data contains distribution of enrolled students based on race such as hispanic, asian, multiracial, native etc.
#     * **Colour**: Here the data distributed enrolled student by black, white.
#     * **Residency Status**: This means whether the enrolled student is resident or non resident in the US.
#     * **Salary/Pay after Studies**:Here, data on the average pay of students is given as early_career_pay, mid_career_pay.
#
#
#
# * In terms of the university, it gives good information on the following criteria:
#
#     *  **Costing**: Data on several fees and cost of each university is available such as room_and_board,in_state_tuition, in_state_total, out_of_state_tuition, out_of_state_total.
#     * **Type of University**: We can also know the categories of university such as Private, Public, or For Profit.
#     * **Duration of Degree Offered**: Data on how long programmes took from enrolled students. This is given as degree_length.

# %% [markdown]
# ### 2. Which facts or principles do you need to know about US university system to make a good sense of this dataset?
#
# * First, we need to understand what of different types of US higher education. This is important because from the data we are given information about **colleges** as well as **university**.
#
# According to Study in the USA(2021),there are 4 types of higher education:
#
# * **State College or University**: A state univeristy or college is owned and run by the government. Each US state owns at least 1 state univeristy and possibly several state colleges.
#
# * **Private College or University**: This is not owned or run by the goverment but individuals.
#
# * **Community College**: These are colleges that award associate degrees and certfications which could be transferable to 4 year degree colleges or universities or work.
#
# * **Institute of Technology**: Specializes in STEM programmes.
#
# Also we need to know the duration of study for the US university system.
#
# * Community colleges take about 2 years to complete in the US. According to College Board (2021) more than 40 percent of U.S. undergraduate students attend community colleges.
#
#
# * University and Colleges take 4 years for undergraduate study in the US.
#
#
# Then, we need to be aware of the average costing of universities and colleges across states in the US.
#
# **Sources**:
#
# * https://www.studyusa.com/en/a/58/understanding-the-american-education-system
# * https://bigfuture.collegeboard.org/find-colleges/how-to-find-your-college-fit/community-college-faqs

# %% [markdown]
# ### 3. Which things about the data you have at hand you do not know for sure and have to assume?
#
# * From the dataset, we are not told what type of degree the enrolled students did in the university. However,we can assume that the data was collected from undergraduate students because the degree_length ( 2 years and 4 years).
#
#
# * Even though the currency of the cost was not stated,we assume all cost are in dollars($)
#
#
# * We are also not told last date the data was collated. Hence we assume that latest data available for analysis.

# %% [markdown]
# ### 4.  In this project, you will have to predict out-of-state total cost. Do students choose university solely based on the cost? Which other factors might be important?
#
# Out-of-state total cost is the amount (tuition + living expenses) a student pays during the duration of study. It is definitely an important factor for students in choosing a university because you can only attend a university you can afford.
#
# However, there are other factors that might be important.
#
# * Choice of Study Program for Majors/Minors
# * Extracurricular Activities Integration
# * Class size
# * School Rankings
# * Safety
# * Internship and Job Opportunities

# %% [markdown]
# ### 5. To whom is this cost variable more important than the other three?
#
# From the dataset, we have 4 cost variables recorded. These include: In-state tuition, Out-of-state tuition, In-state total cost and Out-of-state total cost. Out-of-state cost usually applies to students outside the state.
#
# The Out-of-state total cost would definitely be more important to:
#
# * Students who are not resident in the state of the university.
# * International students
# * Students  not have any support from scholarship, tuition waivers or sponsorship.
#
# This is because Out-of-state students pay more because they do not pay taxes to the state in which the university is located.

# %% [markdown]
# ### 6. Formulate a reasonable organizational/business goal, execution of which would require analysis of out-of-state total cost in this dataset.
#
# As the higher education analytics company, most of the questions received from clients revolve around the following:
#
# * How much will it cost?
# * How much do we save?
#
# These are the most critical challenges in higher education planning.
#
# Hence, using the US education data, we are offering a solution by **predicting the out-of-state total cost for public and private universities and colleges**.
#
# This would facilitate data-driven decision making for the prospective student and improve planning and budgeting.

# %% [markdown]
# ###  7. Which variable would you have to optimize for this goal? What variables would you have to constrain for it to be reasonable?
#
# For this goal, I would have to optimize all cost variables. It is assumed that the out_of_state_tuition and room_and_board would need to be paid attention to  as these are variables from which the target variable is derived.
#
# I would have to constrain adding the target variable which is out_of_state_total because that is what we are predicting.

# %% [markdown]
# ### 8. Which data manipulations would you have to perform for an analysis or an ML system for this goal? What would you have to predict? Would classification or regression be more suitable, and why?
#
#
#
# **a.	Data Cleaning:**
# * As a next step, this project will evaluate the missing values within the data set to better understand how to deal with them. First, we search for patterns within the variables through visual inspection. There, we speculate how the distribution of the missing values would look like if they were available by discussing if the missing data is “missing completely at random”, “missing at random” or “not missing at random.” Also data types are checked, to ensure that accuracy in the analysis. Before doing the analysis and prediction, the data is checked if it is normalized.
#
#
# **b.	Data Exploration:**
# * From the data set we explore basic questions to have a better understanding of the data. For example,  which schools are attended by most students? Which universities have the lowest out-of-state total cost? How is the out-of-state total cost to th type of university?
#
#
# **c.	Feature Engineering and Feature Selection:**
#
# * We determine which variables are most correlated to the predicting variable which is out-of-state total cost.
#
# * Then,  we need features could be created from existing variables to better prediction
#
# * Categorical variables could be dealt with using one-hot encoding.
#
# **d.	Predictive Modelling**
#
# * At this point, we determine which machine learning algorithm would be most suitable. For this project,it we would most suitable to use the **regression** machine learning technique.
#
# * Regression is the best suited because we want to describe the relationships between the independent variables and the dependent variable. In this project, the dependent variable is the out-of-state-cost and we would be determining with features in the educational data.
#
#
# **e.	Data-Driven Insights:**
#
# * From the analysis, we would be able to give data-driven insights and recommendation to prospective students as it relates to planning and budgeting the out-of-state cost.
#
#
#
#
# **I would have to predict the out_of_state_total cost to acheve this business goal**.
#
#
# **Regression model would be more suitable because we are predicting output that is continuous value, which is predicting the out_of_state_total cost**.

# %% [markdown]
# ## Problem 3: EDA and Data preprocessing

# %% [markdown]
# #### Check how many categorical features exist and for each categorical feature see how many samples belong to each category.

# %%
univ_data.head(2)
# Out:
#                      name  total_enrollment      state  n_native  n_asian  \
# 3         Academy College               127  Minnesota         1       10
# 5  Adams State University              3154   Colorado        37       37
#
#    n_black  n_hispanic  n_pacific  n_nonresident  n_total_minority  ...  \
# 3       14           6          3              0                35  ...
# 5      191         812         10              0              1213  ...
#
#    degree_length  room_and_board  in_state_tuition  in_state_total  \
# 3         2 Year             NaN             17661           17661
# 5         4 Year          8782.0              9440           18222
#
#   out_of_state_tuition out_of_state_total early_career_pay  mid_career_pay  \
# 3                17661              17661              NaN             NaN
# 5                20456              29238          44400.0         81400.0
#
#    make_world_better_percent  stem_percent
# 3                        NaN           NaN
# ...

# %% [markdown]
# From the dataset, there are **4** categorical variables
#
# * state
# * state_code
# * type
# * degree_length

# %%
# Number of samples by state
univ_data['state'].value_counts()
# Out:
# New York         121
# Massachusetts     78
# Washington        45
# Minnesota         45
# New Jersey        40
# Connecticut       30
# Colorado          29
# New Hampshire     18
# North Dakota      16
# Hawaii             3
# Name: state, dtype: int64

# %%
# Number of samples by state_code
univ_data['state_code'].value_counts()
# Out:
# NY    121
# MA     77
# MN     45
# WA     44
# NJ     40
# CT     31
# CO     29
# NH     18
# ND     16
# HI      3
# OH      1
# Name: state_code, dtype: int64

# %% [markdown]
# Each state has a unique state_code.However, we notice from the plot that there are 11 state_codes as opposed to 10 states represented in the data. This is because the last state code **OH** is an error. This would be investigated and dealt with.

# %%
# Check the data where state code is represented as "OH"
state_code = ['OH'] 
univ_data[univ_data['state_code'].isin(state_code)]
# Out:
#                                     name  total_enrollment       state  \
# 2037  Washington State Community College              1623  Washington
#
#       n_native  n_asian  n_black  n_hispanic  n_pacific  n_nonresident  \
# 2037         8        3       16          21          1              0
#
#       n_total_minority  ...  degree_length  room_and_board  in_state_tuition  \
# 2037                67  ...         2 Year             NaN              4736
#
#       in_state_total out_of_state_tuition out_of_state_total early_career_pay  \
# 2037            4736                 4766               4766              NaN
#
#       mid_career_pay  make_world_better_percent  stem_percent
# 2037             NaN                        NaN           NaN
#
# [1 rows x 26 columns]

# %% [markdown]
# From observation, we see that the university is actually in Washington. Hence, we would correct the state code.

# %%
# change state code OH to WA
univ_data['state_code'] = univ_data['state_code'].replace(['OH'],'WA')

# %%
# Number of samples by type
univ_data['type'].value_counts()
# Out:
# Private       211
# Public        197
# For Profit     17
# Name: type, dtype: int64

# %%
# Number of samples by degree_length
univ_data['degree_length'].value_counts()
# Out:
# 4 Year    262
# 2 Year    163
# Name: degree_length, dtype: int64

# %% [markdown]
# ### 2. Visualize the distributions of all features in the data set and summarize your findings.

# %%
# Print all column names in dataset
print(univ_data.columns.values)
# Out:
# ['name' 'total_enrollment' 'state' 'n_native' 'n_asian' 'n_black'
#  'n_hispanic' 'n_pacific' 'n_nonresident' 'n_total_minority'
#  'n_multiracial' 'n_unknown' 'n_white' 'n_women' 'state_code' 'type'
#  'degree_length' 'room_and_board' 'in_state_tuition' 'in_state_total'
#  'out_of_state_tuition' 'out_of_state_total' 'early_career_pay'
#  'mid_career_pay' 'make_world_better_percent' 'stem_percent']

# %%
univ_numeric
# Out:
#       total_enrollment  n_native  n_asian  n_black  n_hispanic  n_pacific  \
# 3                  127         1       10       14           6          3
# 5                 3154        37       37      191         812         10
# 6                 7610        10      554      857        1007          6
# 7                 4247        18       38      126         135          2
# 12                5001        33       63       78        1631          9
# ...                ...       ...      ...      ...         ...        ...
# 2143               151         0        0        0           0          0
# 2144               122         0        0        0           0          0
# 2147                98         0        0        0           0          0
# 2148              6348         6      289      144         199         15
# 2150               631         0        0        0           0          0
#
#       n_nonresident  n_total_minority  n_multiracial  n_unknown  ...  n_women  \
# ...

# %%
# Create data frame with only numerical variables
univ_numeric= univ_data.drop(['name','type', 'state','state_code','degree_length'], axis = 1)

 # Create data frame with only categorical variables and identifier variables
univ_categorical = univ_data[['state','state_code','degree_length', 'type']]

# %%
# Visualize Numerical Variables
# univ_numeric.hist(bins=15, figsize=(10, 5), layout=(7, 3));

# %%
# Get column names
num_var = univ_numeric.select_dtypes(include=['int64', 'float']).columns.tolist()
number_of_columns = 21
number_of_rows = int(len(num_var)-1 / number_of_columns)

# Plot distribution of all variables
plt.figure(figsize=(number_of_columns, number_of_rows))
for i in range(0, len(numeric_feature)):
    plt.subplot(6, 4, i+1)
    sns.histplot(univ_numeric[numeric_feature[i]], kde=True, stat="density" )
    #plt.tight_layout()

# %%
# # Visualize Numerical Variables
# plt.rcParams["figure.figsize"] = [15,4]  #set the graph to a smaller size 
# no_of_columns = 21               # in-case you want to try with a smaller subset of graphs to save execution time / CPU consumption
# for i in range(0,no_of_columns) :
#     col_name = univ_numeric.columns[i]  # get the column name to identify the graph
#     x=univ_numeric[col_name]
#     plt.xlabel(col_name)         # The column name will be the x-label ( just to identify )
#     k=plt.hist(x, bins=15)       # Change the right number of bins to get it more/less granular 
#     plt.show()

# %% [markdown]
# From the visualization, most of the variables are skewed to the right.
#
# Also, we can analyse specfic for each of the variables
#
# * **total_enrollment**: From the plot, most universities enrolled less than 10,000 students.
#
# * **n_native**: From the plot, most universities enrolled less than 100 native students
#
# * **n_asian**: From the plot, most universities enrolled less than 50 asian students.However,some universities above 1000 asian students that enrolled.
#
# * **n_black**: From the plot, there are more blacks represented when compared to natives and asians. Some universities have up to 15000 enrolled black students.
#
# * **n_white**: From the plot, most universities enrolled between less than 5000 white students.
# * **room_and_board**: From the plot, most room and board cost between 12,000 and 16,000 dollars
# * **in_state_total**: Most universities have an in-state total cost less than 15,000 dollars
# * **out_of_state_total**: From the plot, there are three noticable groups of universities based on the out_of_state_total
#      * Universities that have out_of_state_total cost less than 20,000 dollars
#      * Universities that have out_of_state_total cost between 20,000 dollars and 50,000 dollars.
#      * Universities that have out_of_state_total cost greater than 50,000 dollars.
# * **early_career_pay**: From the plot, most students earn between 45,000 and 58,000 dollars in their early career.
# * **mid_career_pay**: From the plot, most students earn between 80,000 and 100,000 dollars mid career.
# * **make_world_better_percent**: For the data available for this feature, most universities have 45%-55% of students who studied programs that relate to making the world a better.
# * **stem_percent**: For the data available for this feature, less than 25% of students studied STEM related program at the university.

# %%
# Visualize Categorical Variables
fig, ax = plt.subplots(1, 4, figsize=(15, 4))
for variable, subplot in zip(univ_categorical, ax.flatten()):
    sns.countplot(univ_categorical[variable], ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %% [markdown]
# For the categorical variables
#
# * There are 10 distinct states represented in the dataset with New York have the highest number of universities at 120.
#
#
# * There are two types of degrees that students enroll into based on the degree length. We could infer that the 2 years degree represents **community college** and the 4 years degree represents **public and private state universities and colleges**.
#
#
# * There are about 260 universties that offer 4 years degreees and about 160 universities that offer 2 years degrees.
#
#
# * There are three types of universities based on the type. Most Universities consist of private and public universities.
#
#
#
# * 211 universities are private, 197 universties are public and 17 universities are for profit.

# %% [markdown]
# ### 3. Split the data set into a training (70%) and a test (30%) set with the help of stratified sampling based on the degree length. Report mean and standard deviation for out_of_state_total in train and test data set.

# %%
# Split the dataset into train and test sets with stratification on the degree length
from sklearn.model_selection import train_test_split
train, test = train_test_split(univ_data, test_size=0.3, random_state=1, stratify=univ_data['degree_length'])

print(train.shape, test.shape)

X_train = train.loc[:, train.columns != 'out_of_state_total']
y_train = train.out_of_state_total

X_test = test.loc[:, train.columns != 'out_of_state_total']
y_test = test.out_of_state_total

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (297, 26) (128, 26)
# (297, 25) (128, 25) (297,) (128,)

# %% [markdown]
# #### Report the mean and standard deviation of out_of_state_total in train and test data set.

# %%
# Mean and standard deviation in train data set
y_train.describe()
# Out:
# count      297.000000
# mean     32589.030303
# std      21445.114001
# min       3460.000000
# 25%      13172.000000
# 50%      29546.000000
# 75%      50972.000000
# max      74001.000000
# Name: out_of_state_total, dtype: float64

# %% [markdown]
# * The mean of the out_of_state_total is : **32589.030303**
# * The standard deviation of the out_of_state_total is : **21445.114001**

# %%
y_test.describe()
# Out:
# count      128.000000
# mean     31233.406250
# std      20696.281619
# min       3980.000000
# 25%      13133.000000
# 50%      25585.000000
# 75%      49611.250000
# max      70942.000000
# Name: out_of_state_total, dtype: float64

# %% [markdown]
# * The mean of the out_of_state_total is : **31233.406250**
# * The standard deviation of the out_of_state_total is : **20696.281619**

# %% [markdown]
# ## Problem 4: Data Visualization
#
# ### Use total_enrollment and all demographic features like n_women, n_white etc to create scatterplots and add a meaningful representation of the target out_of_state_total feature.

# %%
#Create copy of dataframe
univ_scatter = pd.DataFrame(univ_data).copy()

# %%
pd.qcut(univ_scatter['out_of_state_total'], q=5,precision = 0)
# Out:
# 3       (12236.0, 18575.0]
# 5       (18575.0, 36444.0]
# 6       (36444.0, 54748.0]
# 7       (18575.0, 36444.0]
# 12      (12236.0, 18575.0]
#                ...
# 2143    (12236.0, 18575.0]
# 2144     (3459.0, 12236.0]
# 2147    (12236.0, 18575.0]
# 2148    (54748.0, 74001.0]
# 2150    (12236.0, 18575.0]
# Name: out_of_state_total, Length: 425, dtype: category
# Categories (5, interval[float64]): [(3459.0, 12236.0] < (12236.0, 18575.0] < (18575.0, 36444.0] < (36444.0, 54748.0] < (54748.0, 74001.0]]

# %% [markdown]
# We have sucessfully created five categories based on the out_of_state_total variable. Now we would assign category names to each range.
#
#
# * **class 0**: less than 12,236 dollars
# * **class 1**: Between 12,236 and 18575 dollars
# * **class 2**: Between 18,575 and 36,444 dollars
# * **class 3**: Between 36,444 and 54,748 dollars
# * **class 4**: Between 54,748 and 74,001 dollars

# %%
# Create categorical variables from out_of_state_total
univ_scatter['out_of_state_total'] = pd.qcut(univ_data['out_of_state_total'],
                            q=[0, .2, .4, .6, .8, 1],
                            labels=False,
                            precision=0)

# %%
univ_scatter.columns
# Out:
# Index(['name', 'total_enrollment', 'state', 'n_native', 'n_asian', 'n_black',
#        'n_hispanic', 'n_pacific', 'n_nonresident', 'n_total_minority',
#        'n_multiracial', 'n_unknown', 'n_white', 'n_women', 'state_code',
#        'type', 'degree_length', 'room_and_board', 'in_state_tuition',
#        'in_state_total', 'out_of_state_tuition', 'out_of_state_total',
#        'early_career_pay', 'mid_career_pay', 'make_world_better_percent',
#        'stem_percent'],
#       dtype='object')

# %% [markdown]
# #### Plots by demographic variables

# %%
# Plot variables
plt.figure(figsize=(18,28))
d_cols = num_var[1:12]
for i in range(0, len(d_cols)):
    plt.subplot(8, 3,i+1)
    sns.set_style('whitegrid')
    sns.scatterplot(y=univ_scatter['total_enrollment'], x=univ_scatter[d_cols[i]], hue=univ_scatter['out_of_state_total'])
    #plt.tight_layout()

# %% [markdown]
# ### 1. Describe what can be seen and interpret it.

# %% [markdown]
# From the plot,
#
# * Most natives attend less expensive universities.
# * Non resident students attend the most expensive universities which could be private universties.
# * The number of women being enrolled in  the universities is increasing.
# * Hispanic students attend both expensive and less expensive universities.
# * White students are kind of evenly distributed in the type of universties they attend in terms of cost. A good number go to expensive as well as less expensive schools.

# %% [markdown]
# ### 2. Which demographic characteristics are more pronounced for more expensive universities?
#
# From the scatter plots, the following variables are more pronounced for expensive universities
#
#
# * **n_non_resident**: Most of the data belong to class 4 of the out_of_total variable which represents the most expensive categories of universities.
#
# * **n_multiracial** and **n_asian** : Most of the data belong to class 3 and 4 of the out_of_total variable which represents expensive categories of universities.
#
#
# This makes sense because most people who fall into this categories international students and non-residents

# %% [markdown]
# ### 3. Write down your assumptions about why universities with lower costs tend to attract certain groups more than more expensive universities.
#
#
# * **n_native**: These are students who were born and raised in that particular state. Hence, they are likely go for universities in which theypay in_state_tuition which is less cheaper.
#
# * Also natives are most likely more comfortable with the system, hence, they are comfortable with picking universities that would not cost them a lot.
#
# * Also, because natives are resident, they could pick universities that are closest to them and not consider cost.
#
# * **n_total_minority**: These are students who are citizens of the U.S who are African American, Hispanic, Native American, Asian Pacific, or Asian Indian. Because they ae citizens,they also tend to pay in_tuition fees and attend public unversities which are subsdized by the government.

# %% [markdown]
# ### 4. Which important considerations might these visualization conceal, rather than reveal? Produce visualizations that illustrate the findings that might be unobvious from scatterplots above.

# %% [markdown]
# * Scatter plots cannot give you the exact extent of correlation.
# * The scatter plot does not show a quantitative measurement of the relationship between the variables.
# * Does not show you the relationship for more than two variables.
# * It does not give you a view of the statistical distribution of the variables.e.g mean, median

# %%
# Plot box plot
plt.figure(figsize=(15,10))
for i in range(0, len(numeric_feature)):
    plt.subplot(5, 6,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(y=univ_scatter[numeric_feature[i]], color='blue', width=0.8)
    plt.tight_layout()

# %% [markdown]
# ## Problem 5: Correlation

# %% [markdown]
# #### Create correlation plots between variables

# %%
plt.figure(figsize=(20, 10))
corrplot = univ_data.corr()
sns.heatmap(corrplot, annot=True)
plt.show()

# %% [markdown]
# ### 1. Which feature has the strongest correlation to the target feature? Plot the correlation between them exclusively.
#
# Out_of_state_tuition is most correlated to out_of_state_total. The variable has a correlation coefficient of **0.981** to the target variable. This implies that this variable is highly positively correlated to the target variable.
#
# * out_of_state_tuition

# %%
# Plot correlation between out_of_state_tuition and out_of_state_total
sns.regplot(x=univ_data["out_of_state_tuition"], y=univ_data["out_of_state_total"])
# Out:
# <AxesSubplot:xlabel='out_of_state_tuition', ylabel='out_of_state_total'>

# %%
# # Plot correlation between in_state_tuition and out_of_state_total
# sns.regplot(x=univ_data["in_state_total"], y=univ_data["out_of_state_total"])

# %% [markdown]
# ### 2.Describe and interpret what you can see in this correlation plot. Any unusual occurrences?
#
#
# * From the correlation plot, all cost variables are highly positively correlated with one another. This means as one of these variables increase, the other also increases. These variables include: out of state tuition, in state tuition, in state cost, out of state total, room and board. This is as a result of the dependence of these variables to their individual derivation.
#
# ![image.png](attachment:image.png)
#
#
# * n_asian and n_nonresident variables are the most correlated demographic variables tothe cost variables which incluedes the target variable out of state total.
#
#
# * However, most of the demographic variables are negatively correlated with each other.
#
# ![image-2.png](attachment:image-2.png)
#
#
# * Total enrollment has a low correlation to the cost variables. This may imply that total enrollment of students does not have a strong effect on the out of state total cost.
#
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 3. Which three features correlate the most with make_world_better_percent, a percentage of alumni who make the world a better place?

# %% [markdown]
# From the correlation plot, the three variables most correlated to make_world_better_percent are:
#
# * out_of_state total with a correlation coefficient of **-0.39**
# * out_of_state tuition with a correlation coefficient of **-0.36**
# * in_state total with a correlation coefficient of **-0.34**
#
# They are negatively correlated to the make_world_better_percent

# %% [markdown]
# ### 4. Choose the strongest of these three correlations and propose four hypotheses about the nature of the link between these variables
#
# Now we would be creating hypotheses using the out_of_state_total.
#
# #### Hypothesis 1:
#
# * out_of_state total with a correlation coefficient of **-0.39**
#
#     * H0: Universities with low out_of_state total do not contribute more to make_world_better_percent
#
#     * **H1: Universities with low out_of_state total contributes more to make_world_better_percent**
#
#
# * **P < 0.05 - Reject H0 and accept H1**
#
# * **P > 0.05 - Failed to reject H0, so we accept H0**
#
# From the spearman correlation, reject H0 and accept H1 because p < 0.05

# %%
# Hypothesis 1
from scipy.stats.mstats import spearmanr
spearmanr(univ_data['out_of_state_total'], univ_data['make_world_better_percent'])
# Out:
# SpearmanrResult(correlation=-0.3770461365858081, pvalue=8.340301282507014e-16)

# %% [markdown]
# #### Hypothesis 2:
#
# * out_of_state tuition with a correlation coefficient of **-0.36**
#
#    * H0: Students who make the world better place do not prefer less out_of_state tuition
#
#    * **H1: Students who make the world better place prefer less out_of_state tuition**
#
#
#
# From the spearman correlation, reject H0 and accept H1 because p < 0.05

# %%
# Hypothesis 2
spearmanr(univ_data['make_world_better_percent'], univ_data['out_of_state_tuition'])
# Out:
# SpearmanrResult(correlation=-0.38203484539881666, pvalue=3.230524421386598e-16)

# %% [markdown]
# #### Hypothesis 3:
#
# * in_state total with a correlation coefficient of **-0.34**
#
#   * H0: in_state total is not positively correlated with  out_of_state total in a university
#
#   * **H1: in_state total is positively correlated with  out_of_state total in a university**
#
# From the spearman correlation, reject H0 and accept H1 because p < 0.05

# %%
# Hypothesis 3
spearmanr(univ_data['out_of_state_total'], univ_data['in_state_total'])
# Out:
# SpearmanrResult(correlation=0.9638895110262568, pvalue=3.452405404391048e-245)

# %% [markdown]
# #### Hypothesis 4:
#
#   * H0 : out_of_state total is not positively correlated with out_of_state tuition
#
#   * **H1: out_of_state total is positively correlated with out_of_state tuition**
#
# From the spearman correlation, reject H0 and accept H1 because p < 0.05

# %%
# Hypothesis 4
spearmanr(univ_data['out_of_state_total'], univ_data['out_of_state_tuition'])
# Out:
# SpearmanrResult(correlation=0.9607318534201612, pvalue=1.2354391350340982e-237)

# %% [markdown]
# ### 5. Which hypothesis do you find the most plausible? Which sources are there supporting it?
#
#
# I find Hypothesis 4 most plausible which is **out_of_state total is positively correlated with out_of_state tuition**
#
# This is because the out_of_state total based on the given universities dataset is the total **sum of out_of_state_tuition and room_and_board**. This implies that the higher the out_of_state_tuition, the higher the out_of_state total.

# %% [markdown]
# ### 6. Which features do you lack in this dataset, which would have helped you determine whether you hypothesis is likely true?
#
# * The inflation rate

# %% [markdown]
# ### 7. Explain the difference between Pearson and Spearman correlation coefficients. Which of them have you just used in this problem? Which of them would be more feasible for the analysis you are doing?
#
# * **Pearson correlation coefficents** are used to determine the linear relationship between two continuous variables and how to change with each other.
#
# * **Spearman correlation coefficients** are used to determine the relationship between two continuous or ordinal variables. Here, the changes between the two variables occur together but not necessarily at the constant rate. This is called a monotonic relationship.
#
# For this analysis, the spearman correlation is more feasible because it doesn’t assume normality between variables.

# %% [markdown]
# ## Problem 6: Correlation 2

# %%
univ_data.head()
# Out:
#                             name  total_enrollment      state  n_native  \
# 3                Academy College               127  Minnesota         1
# 5         Adams State University              3154   Colorado        37
# 6             Adelphi University              7610   New York        10
# 7   Adirondack Community College              4247   New York        18
# 12        Aims Community College              5001   Colorado        33
#
#     n_asian  n_black  n_hispanic  n_pacific  n_nonresident  n_total_minority  \
# 3        10       14           6          3              0                35
# 5        37      191         812         10              0              1213
# 6       554      857        1007          6            436              2587
# 7        38      126         135          2              9               395
# 12       63       78        1631          9              4              1911
#
# ...

# %%
# Print all column names in dataset
print(univ_data.columns.values)
# Out:
# ['name' 'total_enrollment' 'state' 'n_native' 'n_asian' 'n_black'
#  'n_hispanic' 'n_pacific' 'n_nonresident' 'n_total_minority'
#  'n_multiracial' 'n_unknown' 'n_white' 'n_women' 'state_code' 'type'
#  'degree_length' 'room_and_board' 'in_state_tuition' 'in_state_total'
#  'out_of_state_tuition' 'out_of_state_total' 'early_career_pay'
#  'mid_career_pay' 'make_world_better_percent' 'stem_percent']

# %% [markdown]
# ### 1. Explain why you think a combination will be useful before you create them.

# %% [markdown]
# It is useful to create additional features from existing ones as this can improve the machine learning model accuracy. This process is known as **feature engineering**.
#
#
# Possible new features from universities dataset include:
#
# * **n_men**: This is the number of enrolled students that are men. This will be computed by substracting the n_women from the total_enrollment.
#
# * **n_stem**: This is the number of enrolled students who studied a STEM programs. It can be gotten by the product of the stem_percent and total_enrollment.
#
# * **n_make_world_better**: This is the number of enrolled students who studied programs they believe make the world better. It can be gotten by the product of the make_world_better_percent and total_enrollment.

# %%
# Create n_men variable 
univ_data['n_men'] = univ_data['total_enrollment'] - univ_data['n_women']

# Create n_stem variable 
univ_data['n_stem'] = univ_data['total_enrollment'] * univ_data['stem_percent']

# Create n_make_world_better variable 
univ_data['n_make_world_better'] = univ_data['total_enrollment'] * univ_data['make_world_better_percent']

# %%
univ_data.head(3)
# Out:
#                      name  total_enrollment      state  n_native  n_asian  \
# 3         Academy College               127  Minnesota         1       10
# 5  Adams State University              3154   Colorado        37       37
# 6      Adelphi University              7610   New York        10      554
#
#    n_black  n_hispanic  n_pacific  n_nonresident  n_total_minority  ...  \
# 3       14           6          3              0                35  ...
# 5      191         812         10              0              1213  ...
# 6      857        1007          6            436              2587  ...
#
#    in_state_total  out_of_state_tuition  out_of_state_total  early_career_pay  \
# 3           17661                 17661               17661               NaN
# 5           18222                 20456               29238           44400.0
# 6           54690                 38660               54690               NaN
#
# ...

# %% [markdown]
# ### 2. Check their correlation with the out_of_state_total in comparison with the other features from before. Show the correlations with the target feature in a descending order.

# %%
plt.figure(figsize=(20, 10))
corrplot = univ_data.corr()
sns.heatmap(corrplot, annot=True)
plt.show()

# %%
# Correlation of features with target variable in a descending order.
corr_matrix = univ_data.corr()
print(corr_matrix["out_of_state_total"].sort_values(ascending=False))
# Out:
# out_of_state_total           1.000000
# out_of_state_tuition         0.981424
# in_state_total               0.980693
# in_state_tuition             0.949623
# room_and_board               0.815587
# mid_career_pay               0.707357
# early_career_pay             0.664269
# stem_percent                 0.442539
# n_nonresident                0.356519
# n_stem                       0.313223
# n_asian                      0.194903
# n_men                        0.102880
# total_enrollment             0.084103
# n_multiracial                0.069032
# n_women                      0.065655
# n_unknown                    0.061276
# n_white                      0.054605
# n_make_world_better         -0.017801
# n_total_minority            -0.025176
# n_pacific                   -0.066377
# n_hispanic                  -0.080531
# n_black                     -0.106079
# n_native                    -0.160796
# make_world_better_percent   -0.387436
# ...

# %% [markdown]
# ### 3. Do your newly created features have higher correlation with the target feature?

# %% [markdown]
# From the correlation matrix above, we can see that the newly created features have higher correlation with the target variable when compared to the features from which they were created from
#
# * **n_men** = 0.102880 and **n_women** = 0.065655
# * **n_make_world_better** = -0.017801 and **make_world_better_percent** = -0.387436
#
# However, the stem_percent still has a higher correlation with the target variable when compared to the n_stem variable that was created.
#
# * **n_stem** = 0.313223 and **stem_percent** = 0.442539

# %% [markdown]
# ### 4. Take a look at the data from tuition_income dataset and decide which features or combinations of features you think will also be beneficial for prediction. Repeat steps 1-3 for them. Note that you may need to make some extra transformations to add them.

# %%
data_tuition.head()
# Out:
#                                 name state  total_price  year     campus  \
# 0  Piedmont International University    NC        20174  2016  On Campus
# 1  Piedmont International University    NC        20174  2016  On Campus
# 2  Piedmont International University    NC        20174  2016  On Campus
# 3  Piedmont International University    NC        20174  2016  On Campus
# 4  Piedmont International University    NC        20514  2017  On Campus
#
#       net_cost         income_lvl
# 0  11475.00000        0 to 30,000
# 1  11451.00000   30,001 to 48,000
# 2  16229.00000   48_001 to 75,000
# 3  15592.00000  75,001 to 110,000
# 4  11668.39249        0 to 30,000

# %% [markdown]
# #### First,  we clean up the income_level column

# %%
data_tuition['income_lvl'] = data_tuition['income_lvl'].astype('str')

# %%
# Convert datatype from object to string
data_tuition['income_lvl'] = data_tuition['income_lvl'].astype('string')

# %%
# replace "_" with ","
data_tuition['income_lvl'] = data_tuition['income_lvl'].str.replace('_',',')

# %%
data_tuition.dtypes
# Out:
# name            object
# state           object
# total_price      int64
# year             int64
# campus          object
# net_cost       float64
# income_lvl      string
# dtype: object

# %%
data_tuition.head()
# Out:
#                                 name state  total_price  year     campus  \
# 0  Piedmont International University    NC        20174  2016  On Campus
# 1  Piedmont International University    NC        20174  2016  On Campus
# 2  Piedmont International University    NC        20174  2016  On Campus
# 3  Piedmont International University    NC        20174  2016  On Campus
# 4  Piedmont International University    NC        20514  2017  On Campus
#
#       net_cost         income_lvl
# 0  11475.00000        0 to 30,000
# 1  11451.00000   30,001 to 48,000
# 2  16229.00000   48,001 to 75,000
# 3  15592.00000  75,001 to 110,000
# 4  11668.39249        0 to 30,000

# %%
data_tuition['income_lvl'].replace(['_'], ',')
# data_tuition.loc[data_tuition['income_lvl'].isin(['_'])] = ''
# Out:
# 0               0 to 30,000
# 1          30,001 to 48,000
# 2          48,001 to 75,000
# 3         75,001 to 110,000
# 4               0 to 30,000
#                 ...
# 209007          0 to 30,000
# 209008     30,001 to 48,000
# 209009     48,001 to 75,000
# 209010    75,001 to 110,000
# 209011         Over 110,000
# Name: income_lvl, Length: 209012, dtype: string

# %% [markdown]
# #### Next, we decide which features or combinations  would be beneficial for prediction

# %% [markdown]
# Possible features from tuition dataset that could be good features for prediction
#
#
# * **avg_net_cost**: This could also be a good variable for prediction as it gives us information of the possible average total cost a student pays and subtracts any possible scholarships for which you may receive.
#
# * **avg_total_price**: This could also be a good variable for prediction as it gives us information on the total cost of the universities over the years.

# %%
# select data
data_tuition1 = data_tuition

# %%
# Next filter out data for the respective states.
tut_state = ['NY', 'MA','WA','MN','NJ','CT',
              'CO','NH','ND','HI'] 
data_tuition1 = data_tuition1[data_tuition1['state'].isin(tut_state)]
data_tuition1
# Out:
#                           name state  total_price  year      campus  \
# 109     Seattle Film Institute    WA        47960  2016  Off Campus
# 110     Seattle Film Institute    WA        49076  2017  Off Campus
# 111     Seattle Film Institute    WA        49076  2017  Off Campus
# 112     Seattle Film Institute    WA        49076  2017  Off Campus
# 113     Seattle Film Institute    WA        49076  2017  Off Campus
# ...                        ...   ...          ...   ...         ...
# 205280         Charter College    WA        37544  2018  Off Campus
# 205281         Charter College    WA        37544  2018  Off Campus
# 205282         Charter College    WA        37544  2018  Off Campus
# 205283         Charter College    WA        37544  2018  Off Campus
# 205284         Charter College    WA        37544  2018  Off Campus
#
#            net_cost         income_lvl
# 109     41842.00000        0 to 30,000
# 110     42815.63786        0 to 30,000
# ...

# %%
# Drop columns not needed
d_tuition=data_tuition1.drop(['state', 'year','campus','income_lvl'], axis = 1)

# %%
# view data
d_tuition.head()
# Out:
#                        name  total_price     net_cost
# 109  Seattle Film Institute        47960  41842.00000
# 110  Seattle Film Institute        49076  42815.63786
# 111  Seattle Film Institute        49076      0.00000
# 112  Seattle Film Institute        49076      0.00000
# 113  Seattle Film Institute        49076      0.00000

# %%
# rename columns
d_tuition.rename(columns={'total_price': 'avg_total_price', 'net_cost': 'avg_net_cost'}, inplace=True)

# %%
# create new variables of the average total price and averge net cost
d_tuition=d_tuition.groupby("name").mean()

# %%
# Join both datasets
univ_data = pd.merge(univ_data, d_tuition, left_on='name', right_on='name', how='left')

# %%
univ_data.head()
# Out:
#                            name  total_enrollment      state  n_native  \
# 0               Academy College               127  Minnesota         1
# 1        Adams State University              3154   Colorado        37
# 2            Adelphi University              7610   New York        10
# 3  Adirondack Community College              4247   New York        18
# 4        Aims Community College              5001   Colorado        33
#
#    n_asian  n_black  n_hispanic  n_pacific  n_nonresident  n_total_minority  \
# 0       10       14           6          3              0                35
# 1       37      191         812         10              0              1213
# 2      554      857        1007          6            436              2587
# 3       38      126         135          2              9               395
# 4       63       78        1631          9              4              1911
#
#    ...  out_of_state_total  early_career_pay  mid_career_pay  \
# ...

# %%
# check correlation with target variables
plt.figure(figsize=(20, 10))
corrplot = univ_data.corr()
sns.heatmap(corrplot, annot=True)
plt.show()

# %%
# Correlation of features with target variable in a descending order.
corr_matrix = univ_data.corr()
print(corr_matrix["out_of_state_total"].sort_values(ascending=False))
# Out:
# out_of_state_total           1.000000
# out_of_state_tuition         0.981424
# in_state_total               0.980693
# in_state_tuition             0.949623
# avg_total_price              0.943023
# room_and_board               0.815587
# avg_net_cost                 0.796736
# mid_career_pay               0.707357
# early_career_pay             0.664269
# stem_percent                 0.442539
# n_nonresident                0.356519
# n_stem                       0.313223
# n_asian                      0.194903
# n_men                        0.102880
# total_enrollment             0.084103
# n_multiracial                0.069032
# n_women                      0.065655
# n_unknown                    0.061276
# n_white                      0.054605
# n_make_world_better         -0.017801
# n_total_minority            -0.025176
# n_pacific                   -0.066377
# n_hispanic                  -0.080531
# n_black                     -0.106079
# n_native                    -0.160796
# ...

# %% [markdown]
# From the correlation matrix above, we can see that the newly created features are highly correlated with the target variable.
#
# * **avg_total_price** having a correlation coefficient of **0.943023**
# * **avg_net_cost** having a correlation coefficient of **0.796736**

# %% [markdown]
# ### 5. The 10 states you were directed to select for analysis weren't selected randomly. In fact, they come from a certain well-known rating, and comprise top-10, bottom-10, middle 10, second or fourth quintile of it. Find how we selected them, and support your claim with reference to the respective rating.
#
# From the countries I was told to select for analysis, It was selected from **List of U.S. states and territories by Human Development Index (HDI) based on wikipedia(2019)**.
#
# The countries selected for analysis are the top 10 U.S states in terms of HDI.
#
# **Source**: https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_Human_Development_Index

# %% [markdown]
# ### 6. Explain the reasoning you used to find this missing information.
#
# To find this data, I started of by checking list of US data based on several metrics such as eduction, number of universities for each US state, states ranked by cost of living etc.
#
# However,I then began to check for common ranking metrics that are linked to education and cost based on our business goal which is to predict out_of_state total. Then, I discovered **HDI** as one of the key metrics.
#
# This was how I stumbled on the ranking data.

# %% [markdown]
# ### 7. Might this statewide score be useful at predicting out-of-state total cost? Explain why or why not. If it is useful, add it to your data and check the correlation.
#
# I think the **Human Development Index** could be a good feature to determine the out_of_state total cost because it consists of key dimensions of human development: a long and healthy life, being knowledgeable and have a decent standard of living.
#
# The HDI is the geometric mean of normalized indices for each of the three dimensions.
#
# * The health dimension is assessed by life expectancy at birth
# * The education dimension is measured by mean of years of schooling for adults aged 25 years and more and expected years of schooling for children of school entering age.
# * The standard of living dimension is measured by gross national income per capita.

# %%
# Adding HDI values for each state

# Import data
hdi = pd.read_csv(r"C:\Users\VICTOR\Downloads\DA_Final_Exam\HDI.csv")

# %%
hdi.head()
# Out:
#      HDI state_code
# 0  0.956         MA
# 1  0.954         CT
# 2  0.953         MN
# 3  0.948         NJ
# 4  0.948         NH

# %%
# Join HDI to existing dataset
univ_data = pd.merge(univ_data, hdi, left_on='state_code', right_on='state_code', how='left')

# %%
# check data
univ_data.head()
# Out:
#                            name  total_enrollment      state  n_native  \
# 0               Academy College               127  Minnesota         1
# 1        Adams State University              3154   Colorado        37
# 2            Adelphi University              7610   New York        10
# 3  Adirondack Community College              4247   New York        18
# 4        Aims Community College              5001   Colorado        33
#
#    n_asian  n_black  n_hispanic  n_pacific  n_nonresident  n_total_minority  \
# 0       10       14           6          3              0                35
# 1       37      191         812         10              0              1213
# 2      554      857        1007          6            436              2587
# 3       38      126         135          2              9               395
# 4       63       78        1631          9              4              1911
#
#    ...  early_career_pay  mid_career_pay  make_world_better_percent  \
# ...

# %%
# Correlation of features with target variable in a descending order.
corr_matrix = univ_data.corr()
print(corr_matrix["out_of_state_total"].sort_values(ascending=False))
# Out:
# out_of_state_total           1.000000
# out_of_state_tuition         0.981424
# in_state_total               0.980693
# in_state_tuition             0.949623
# avg_total_price              0.943023
# room_and_board               0.815587
# avg_net_cost                 0.796736
# mid_career_pay               0.707357
# early_career_pay             0.664269
# stem_percent                 0.442539
# n_nonresident                0.356519
# n_stem                       0.313223
# n_asian                      0.194903
# n_men                        0.102880
# total_enrollment             0.084103
# HDI                          0.082599
# n_multiracial                0.069032
# n_women                      0.065655
# n_unknown                    0.061276
# n_white                      0.054605
# n_make_world_better         -0.017801
# n_total_minority            -0.025176
# n_pacific                   -0.066377
# n_hispanic                  -0.080531
# n_black                     -0.106079
# ...

# %% [markdown]
# From the correlation matrix, HDI is not really correlated to the out_of_state cost.It has a correlation coefficent of **0.082599**

# %% [markdown]
# ### 8. Do any of your new features shine the new light on possible determinants of what makes students feel they are making the world the better place? Explain your insights.

# %%
hdi
# Out:
#      HDI state_code
# 0  0.956         MA
# 1  0.954         CT
# 2  0.953         MN
# 3  0.948         NJ
# 4  0.948         NH
# 5  0.948         CO
# 6  0.946         ND
# 7  0.946         WA
# 8  0.945         HI
# 9  0.944         NY

# %%
univ_data.groupby(['state_code'])['n_make_world_better'].count()
# Out:
# state_code
# CO    10
# CT    16
# HI     3
# MA    21
# MN     7
# ND     7
# NH    10
# NJ    18
# NY    12
# WA    15
# Name: n_make_world_better, dtype: int64

# %% [markdown]
# A lot of students believe they are making the world a better place because of how well the are contributing to th HDI of these cities.

# %% [markdown]
# ## Problem 7: Data cleaning

# %% [markdown]
# ### 1. Find out which variables contain missing values. If there are any, how many values are missing?

# %%
# Check missing Values
pd.DataFrame(univ_data.isnull().sum())
# Out:
#                              0
# name                         0
# total_enrollment             0
# state                        0
# n_native                     0
# n_asian                      0
# n_black                      0
# n_hispanic                   0
# n_pacific                    0
# n_nonresident                0
# n_total_minority             0
# n_multiracial                0
# n_unknown                    0
# n_white                      0
# n_women                      0
# state_code                   0
# type                         0
# degree_length                0
# room_and_board             138
# in_state_tuition             0
# in_state_total               0
# out_of_state_tuition         0
# out_of_state_total           0
# early_career_pay           301
# mid_career_pay             301
# make_world_better_percent  306
# stem_percent               301
# n_men                        0
# n_stem                     301
# n_make_world_better        306
# ...

# %% [markdown]
# From the checking the missing values, we can see the following have missing values:
#
# * room_and_board - 138
# * early_career_pay - 301
# * mid_career_pay - 301
# * make_world_better_percent - 306
# * stem_percent - 301
# * avg_total_price - 40
# * avg_net_cost - 40

# %% [markdown]
# ### 2. Which approaches exist for handling missing data? Describe two approaches of how to handle them. Write one advantage and one disadvantage for each of those methods.

# %% [markdown]
# There are several techniques of dealing with missing data:
#
# * **Deletion**: This has to do with deleting missing values from the data. It could be done in three forms.
#     * **Listwise deletion**: This involves completely deleting the rows and removal of all data that contain missing values.
#     * **Pairwise deletion**: This involves removing only null observations and not the entire row like the listwise deletion technique
#     * **Dropping Columns**: This involves dropping the whole column from the dataset which contains a high percentage (>80%) of missing values.
#
# **Advantage of Deletion Method**
#
# * It is a very fast approach of dealing with missing data.
# * In the case of pairwise deletion, data is preserved and the loss of data is minimized.
#
# **Disadvantage of Deletion Method**
#
# * This technique might not be the best in a situation where the dataset is small. For example,in a machine learning scenerio, the dataset would be to small for the algorithm to learn and predict well. This is a peculiar drawback to the listwise deletion method.
#
#
#
# * **Imputation**:  This involves replacing the missing values with other values. There are several ways of dealing with missing values via imputation.
#
#     * **Imputation with a constant value**: This involves replacing the missing values with a constant value. In most cases, it could be 0 or any other constant value.
#     * **Imputation using statistics**: This involves replacing missing values with statistical values such as mean and median in each column.
#     * **K_Nearest Neighbor Imputation**:This involves replacing the missing values with the nearest non-missing values of its closest neighbors.
#
#
# **Advantage of Imputation Method**
#
# * It helps in preserving the data as it does not expressely remove all missing values.
#
# **Disadvantage of Imputation Method**
#
# * In the case of using statistical or constant value imputation method, it might distort the information of a feature in the dataset if it contains lots of missing values. E.g 80% or more
#
# * In the case of using K_Nearest Neighbor imputation method, the feature to which the technique is applied must not be skewed. This means the distribution of the data must be normalized.
#
# * Also, K_Nearest Neighbor imputation method does works on only numerical variables.

# %% [markdown]
# ### 3. Handle the missing data by methods you find the most suitable. Explain how you chose the method for each column.

# %%
# First we update the trainand test splits to incorperate the newly ccreated features

# Split the dataset into train and test sets with stratification on the degree length
from sklearn.model_selection import train_test_split
train, test = train_test_split(univ_data, test_size=0.3, random_state=1, stratify=univ_data['degree_length'])

print(train.shape, test.shape)

X_train = train.loc[:, train.columns != 'out_of_state_total']
y_train = train.out_of_state_total

X_test = test.loc[:, train.columns != 'out_of_state_total']
y_test = test.out_of_state_total

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (297, 32) (128, 32)
# (297, 31) (128, 31) (297,) (128,)

# %%
# First check the percentage of missing values for each of the features
percent_missing = X_train.isnull().sum() * 100 / len(X_train)
percent_missing
# Out:
# name                          0.000000
# total_enrollment              0.000000
# state                         0.000000
# n_native                      0.000000
# n_asian                       0.000000
# n_black                       0.000000
# n_hispanic                    0.000000
# n_pacific                     0.000000
# n_nonresident                 0.000000
# n_total_minority              0.000000
# n_multiracial                 0.000000
# n_unknown                     0.000000
# n_white                       0.000000
# n_women                       0.000000
# state_code                    0.000000
# type                          0.000000
# degree_length                 0.000000
# room_and_board               31.986532
# in_state_tuition              0.000000
# in_state_total                0.000000
# out_of_state_tuition          0.000000
# early_career_pay             70.707071
# mid_career_pay               70.707071
# make_world_better_percent    72.053872
# ...

# %% [markdown]
# For dealing with the **room_and_board** variable, we would use the imputation method by statistical variables using the mean.
#
# Here, we would be replacing the values of the missing data for room_and_board with the mean values in each state.

# %%
# # check variable distribution
# sns.distplot(X_train['room_and_board'])

# %%
# replace missing values with mean values
X_train["room_and_board"] = X_train.groupby("state").transform(lambda x: x.fillna(x.mean()))

# %% [markdown]
# Then, we also used the imputation method by central tendency using the mean for the early career,mid_career pay, avg_net_cost,avg_total_price variables because they are well correlated to target variable out_of_state total

# %%
X_train['early_career_pay'].fillna((X_train['early_career_pay'].mean()), inplace=True)
X_train['mid_career_pay'].fillna((X_train['mid_career_pay'].mean()), inplace=True)
X_train['avg_total_price'].fillna((X_train['mid_career_pay'].mean()), inplace=True)
X_train['avg_net_cost'].fillna((X_train['mid_career_pay'].mean()), inplace=True)

# %%
# sns.distplot(X_train['early_career_pay'])

# %%
# sns.distplot(X_train['mid_career_pay'])

# %% [markdown]
# Then, we remove the columns for the which have higher than 70% missing data and do not have high correlation withthe target variable out_of_state total
#
# * make_world_better_percent    72%
# * stem_percent                 71%

# %%
X_train=X_train.drop(['make_world_better_percent', 'stem_percent','n_stem', 'n_make_world_better'], axis = 1)

# %%
X_train
# Out:
#                                           name  total_enrollment  \
# 310  Rochester Community and Technical College              5894
# 267                       Ocean County College              9296
# 91                 Community College of Denver             10296
# 337          Southern New Hampshire University             43274
# 201      Massachusetts College of Liberal Arts              1765
# ..                                         ...               ...
# 46                         Brandeis University              5945
# 116                             Elmira College              1482
# 206             McNally Smith College of Music               518
# 239                        New England College              2399
# 70                               Clark College             10911
#
#              state  n_native  n_asian  n_black  n_hispanic  n_pacific  \
# 310      Minnesota        21      243      616         280          5
# ...

# %% [markdown]
# ### 4. Handle the categorical data with one-hot-encoding.

# %%
# select categorical variables
categorical_cols = ['state_code','degree_length', 'type']

X_train= pd.get_dummies(X_train, columns = categorical_cols)

# %%
# Drop name and state column as it is already each state is represented with a unique state_code
X_train=X_train.drop(['name','state'], axis = 1)

# %%
X_train.head()
# Out:
#      total_enrollment  n_native  n_asian  n_black  n_hispanic  n_pacific  \
# 310              5894        21      243      616         280          5
# 267              9296        24      166      539         904         22
# 91              10296       123      535     1322        2598         23
# 337             43274       152      337     2373        1009         33
# 201              1765         7       29      148         116          0
#
#      n_nonresident  n_total_minority  n_multiracial  n_unknown  ...  \
# 310             64              1340            175         78  ...
# 267             71              1798            143        425  ...
# 91             614              5047            446       1142  ...
# 337           1251              3964             60      27213  ...
# 201              7               347             47         75  ...
#
#      state_code_ND  state_code_NH  state_code_NJ  state_code_NY  \
# ...

# %% [markdown]
# ## Problem 8: Feature scaling

# %% [markdown]
# ### 1. What feature scaling methods exist? Name five methods and write a short description for three of them. Pick one to use for this data set.

# %% [markdown]
# Here are five methods of feature scaling:
#
# * **Min-Max Scaling**: This involves substracting the minimum value from all the values in the dataset and then dividing this by the result of the maximum and minimum values which is the range of the dataset.
# * **Normalization**: In this case, we substract the mean values from all the values in the dataset and then divide ths by the result of the range of the dataset.
# * **Standardization**: Here, we replace all datapoints with their respective z-values. It involves ensuring that all features are centred around the mean value with a standard deviation value of 1.
# * **Absolute Maximum Scaling**
# * **Robust Scaling**

# %% [markdown]
# For my dataset, I would be using the **Standardization (z-score method)**.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# fit scaler on data
scaler.fit(X_train.iloc[:,0:21])
# apply transform
X_train.iloc[:,0:21]= scaler.transform(X_train.iloc[:,0:21])

# %%
X_train.columns
# Out:
# Index(['total_enrollment', 'n_native', 'n_asian', 'n_black', 'n_hispanic',
#        'n_pacific', 'n_nonresident', 'n_total_minority', 'n_multiracial',
#        'n_unknown', 'n_white', 'n_women', 'room_and_board', 'in_state_tuition',
#        'in_state_total', 'out_of_state_tuition', 'early_career_pay',
#        'mid_career_pay', 'n_men', 'avg_total_price', 'avg_net_cost', 'HDI',
#        'state_code_CO', 'state_code_CT', 'state_code_HI', 'state_code_MA',
#        'state_code_MN', 'state_code_ND', 'state_code_NH', 'state_code_NJ',
#        'state_code_NY', 'state_code_WA', 'degree_length_2 Year',
#        'degree_length_4 Year', 'type_For Profit', 'type_Private',
#        'type_Public'],
#       dtype='object')

# %%
# View Data
X_train.head()
# Out:
#      total_enrollment  n_native   n_asian   n_black  n_hispanic  n_pacific  \
# 310          0.044862 -0.148437 -0.112872  0.085046   -0.381080  -0.230478
# 267          0.525621 -0.090019 -0.208927  0.024678    0.321654   0.308764
# 91           0.666938  1.837755  0.251387  0.638541    2.229398   0.340484
# 337          5.327283  2.402456  0.004389  1.462512    0.439903   0.657685
# 201         -0.538635 -0.421051 -0.379829 -0.281861   -0.565773  -0.389079
#
#      n_nonresident  n_total_minority  n_multiracial  n_unknown  ...  \
# 310      -0.281343         -0.122115       0.096057  -0.234532  ...
# 267      -0.275185          0.056786      -0.039634  -0.029068  ...
# 91        0.202526          1.325893       1.245192   0.395481  ...
# 337       0.762935          0.902857      -0.391583  15.832572  ...
# 201      -0.331490         -0.509995      -0.446707  -0.236309  ...
#
#      state_code_ND  state_code_NH  state_code_NJ  state_code_NY  \
# ...

# %% [markdown]
# ### 2. Find the feature importance with a quick Random Forest and show them in a plot. What insights do you get out of it

# %%
from sklearn.ensemble import RandomForestClassifier

# Create decision tree classifer object
clf = RandomForestClassifier(random_state=0, n_jobs=-1)
# Train model
model = clf.fit(X_train, y_train)

# Calculate feature importances
importances = model.feature_importances_
# Sort feature importances in descending order
indices = np.argsort(importances)[::-1]

# Plot the feature importance
plt.figure(figsize=(10, 5))
plt.title('Feature Importance')
plt.bar(range(X_train.shape[1]), importances[indices], align='center')
plt.xticks(range(X_train.shape[1]), X_train.columns[indices], rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# From the feature importance plot:
#
# * The in_state_total is the most feature to determine the out_of_total cost.
#
# * All tuition fees (in_state_tuition, out_of_state_tuition) are very good features to predict the out_of_state total.
#
# * The number of white students in the universities play a key role in predicting the out_of_state total.
#
# * The average total price and average net cost per university also have a strong effect on the out_of_state_total.
#
# * Most categorical variables contribute least to determining the out_of_state total.

# %% [markdown]
# ## Problem 9: Test data

# %%
# First check the percentage of missing values for each of the features
percent_missing = X_test.isnull().sum() * 100 / len(X_test)
percent_missing
# Out:
# name                          0.00000
# total_enrollment              0.00000
# state                         0.00000
# n_native                      0.00000
# n_asian                       0.00000
# n_black                       0.00000
# n_hispanic                    0.00000
# n_pacific                     0.00000
# n_nonresident                 0.00000
# n_total_minority              0.00000
# n_multiracial                 0.00000
# n_unknown                     0.00000
# n_white                       0.00000
# n_women                       0.00000
# state_code                    0.00000
# type                          0.00000
# degree_length                 0.00000
# room_and_board               33.59375
# in_state_tuition              0.00000
# in_state_total                0.00000
# out_of_state_tuition          0.00000
# early_career_pay             71.09375
# mid_career_pay               71.09375
# make_world_better_percent    71.87500
# stem_percent                 71.09375
# ...

# %%
# replace missing values with mean values for room and board for each state
X_test["room_and_board"] = X_test.groupby("state").transform(lambda x: x.fillna(x.mean()))

# %%
# Use mean imputation method
X_test['early_career_pay'].fillna((X_test['early_career_pay'].mean()), inplace=True)
X_test['mid_career_pay'].fillna((X_test['mid_career_pay'].mean()), inplace=True)
X_test['avg_total_price'].fillna((X_test['mid_career_pay'].mean()), inplace=True)
X_test['avg_net_cost'].fillna((X_test['mid_career_pay'].mean()), inplace=True)

# %%
# Drop features with high missing values

X_test=X_test.drop(['make_world_better_percent', 'stem_percent','n_stem', 'n_make_world_better'], axis = 1)

# %%
# Handle categorica lvariables with one-hot encoding
categorical_cols = ['state_code','degree_length', 'type']

#import pandas as pd
X_test= pd.get_dummies(X_test, columns = categorical_cols)

# %%
# Drop name and state column as it is already each state is represented with a unique state_code
X_test=X_test.drop(['name','state'], axis = 1)

# %%
# standardize all features using z-score transformation

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# fit scaler on data
scaler.fit(X_test.iloc[:,0:21])
# apply transform
X_test.iloc[:,0:21]= scaler.transform(X_test.iloc[:,0:21])

# %%
# View Data
X_test.head()
# Out:
#      total_enrollment  n_native   n_asian   n_black  n_hispanic  n_pacific  \
# 58          -0.112991 -0.336536 -0.166439  0.874150    0.815265  -0.254376
# 353         -0.311396 -0.336536 -0.541079 -0.328820   -0.293747  -0.278441
# 388         -0.819083 -0.370878 -0.633341 -0.281334   -0.631927  -0.326571
# 372         -0.142625 -0.164825  1.603315 -0.343815   -0.048669   9.058822
# 138          0.436693  0.212940 -0.518712 -0.040574   -0.317023  -0.326571
#
#      n_nonresident  n_total_minority  n_multiracial  n_unknown  ...  \
# 58       -0.440600          0.714998      -0.333975   0.088767  ...
# 353      -0.415115         -0.463665      -0.437213  -0.566970  ...
# 388      -0.445234         -0.590125      -0.565228  -0.595263  ...
# 372      -0.060636          0.711092       4.002024  -0.583613  ...
# 138      -0.183430         -0.240042      -0.127499   0.458244  ...
#
#      state_code_ND  state_code_NH  state_code_NJ  state_code_NY  \
# ...

# %%
# find feature importance
from sklearn.ensemble import RandomForestClassifier


# Create decision tree classifer object
clf = RandomForestClassifier(random_state=0, n_jobs=-1)
# test model
model = clf.fit(X_test, y_test)

# Calculate feature importances
importances = model.feature_importances_
# Sort feature importances in descending order
indices = np.argsort(importances)[::-1]

# Plot the feature importance



plt.title('Feature Importance')
plt.bar(range(X_test.shape[1]), importances[indices], align='center')
plt.xticks(range(X_test.shape[1]), X_test.columns[indices], rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# From the feature importance plot:
#
# * The out_of_state_tuition is the strongest feature to determine the out_of_state_total cost.
#
#
# * The out_of_state_tuition is still the most relevant to determine the out_of_total cost.
#
#
# * All cost variables (in_state_tuition, in_state_tuition total,average total price, average net cost) are important in predicting the out_of_state total.
#
#
# * The number of non_residents students in the universities play a key role in predicting the out_of_state total.
#
#
# * The number of men enrolled in the universities is a good feature to determine out_of_state_total.
#
#
# * Most categorical variables contribute least to determining the out_of_state total.

# %% [markdown]
# ## Problem 10: Regression

# %% [markdown]
# ### Select and train the following regression models on the training set. Linear model, support vector regression, and random forest.

# %% [markdown]
# ### 1. Evaluate the three regression models on the test set. Which model performs best?

# %%
# linear regression model
model_linear_reg = LinearRegression().fit(X_train, y_train) # fit the model
y_predict_linear_reg = model_linear_reg.predict(X_test) #predict the test data

#MSE
mse_linear_reg = mean_squared_error(y_test, y_predict_linear_reg)
print("The MSE for the Linear Regression is {:.4f}.".format(mse_linear_reg)) 

#RMSE
def rmse(predictions, targets):
    return np.sqrt(mean_squared_error(targets, predictions))

rmse_linear_reg = rmse(y_test, y_predict_linear_reg)
rmse_linear_reg

print("The RMSE for the Linear Regression is {:.4f}.".format(rmse_linear_reg))

# R-squared

from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_predict_linear_reg)

print("The R2 score for Linear Regression is {:.4f}.".format(r2))

# Adjusted R-squared
N=y_test.shape[0]
p=37
x = (1-r2)
y = (N-1) / (N-p-1)
adj_rsquared = (1 - (x * y))
print("Adjusted-R2 : " , adj_rsquared)
# Out:
# The MSE for the Linear Regression is 2603189.6516.
# The RMSE for the Linear Regression is 1613.4403.
# The R2 score for Random Forest Regression is 0.9939.
# Adjusted-R2 :  0.9913565202515109

# %%
# Fitting SVR to the dataset 
from sklearn.svm import SVR 
regressor = SVR(kernel = 'rbf') 
regressor.fit(X_train, y_train)

# Predicting a new result 
y_pred_svr = regressor.predict(X_test) 
# y_pred_svr = sc_y.inverse_transform(y_pred_svr)

# Computing MSE
mse_svr_test = mean_squared_error(y_test,y_pred_svr)

print("The MSE for Support Vector Regression is {:.4f}.".format(mse_svr_test))
      
#RMSE:
rmse_svr = rmse(y_test, y_pred_svr)
rmse_svr
print("The RMSE for Support Vector Regression is {:.4f}.".format(rmse_svr))

from sklearn.metrics import r2_score

r2 = r2_score(y_test,y_pred_svr)

print("The R2 score for SVR is {:.4f}.".format(r2))

# Adjusted R-squared
N=y_test.shape[0]
p=37
x = (1-r2)
y = (N-1) / (N-p-1)
adj_rsquared = (1 - (x * y))
print("Adjusted-R2 : " , adj_rsquared)
# Out:
# The MSE for Support Vector Regression is 426741401.3337.
# The RMSE for Support Vector Regression is 20657.7201.
# The R2 score for Random Forest Regression is -0.0041.
# Adjusted-R2 :  -0.416927367552242

# %%
# Fitting Random Forest Regression to the dataset

# import the regressor
from sklearn.ensemble import RandomForestRegressor

# create regressor object
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)

# fit the regressor with x and y data
regressor.fit(X_train, y_train)

# Predicting a new result 
y_pred_forest = regressor.predict(X_test) 
# y_pred_svr = sc_y.inverse_transform(y_pred_svr)

# Computing MSE
mse_forest_test = mean_squared_error(y_test,y_pred_forest)

print("The MSE for Random Forest Regression is {:.4f}.".format(mse_forest_test))
      
#RMSE:
rmse_forest = rmse(y_test, y_pred_forest)
rmse_forest
print("The RMSE for Random Forest Regression is {:.4f}.".format(rmse_forest))


# R-squared

from sklearn.metrics import r2_score

r2 = r2_score(y_test,y_pred_forest)

print("The R2 score for Random Forest Regression is {:.4f}.".format(r2))

# Adjusted R-squared
N=y_test.shape[0]
p=37
x = (1-r2)
y = (N-1) / (N-p-1)
adj_rsquared = (1 - (x * y))
print("Adjusted-R2 : " , adj_rsquared)
# Out:
# The MSE for Random Forest Regression is 5217895.4810.
# The RMSE for Random Forest Regression is 2284.2713.
# The R2 score for Random Forest Regression is 0.9877.
# Adjusted-R2 :  0.9826748028549566

# %%
# Determine best model
Lin_reg = format(rmse_linear_reg)

SVR = format(rmse_svr)

random_forest = format(rmse_forest)

best_model = pd.DataFrame(
    {'Model' : ['Linear_Regression', 'Support Vector Regression','Random Forest'],
    'RMSE': [Lin_reg,SVR,random_forest ]
    })

best_model
# Out:
#                        Model                RMSE
# 0          Linear_Regression  1613.4403154725271
# 1  Support Vector Regression   20657.72013881705
# 2              Random Forest  2284.2713238583465

# %% [markdown]
# Using the RMSE metrics, the **Linear regression model** performed best with an **RMSE of 1613.44** which is lower compared to the other two models.

# %% [markdown]
# ### 2. Explain one approach about how the models can be further optimized.

# %% [markdown]
# We can improve the model by using **feature selection**
#
# Feature selection would help us determine the best attributes which better explains the relationship of the features with target variable.
#
# We can select the useful features based on various metrics like:
#
# * **Domain Knowledge**: Based on domain experience, we select feature(s) which may have higher impact on target variable.
#
# * **Feature selection visualization**: This can help us to visualize the relationship between variables aid selecting the best features.

# %% [markdown]
# ### 3. Based on the data you have at hand and your background knowledge, which problems might you encounter when trying use your best model to predict out-of-state total cost for the next year?
#
# * Gathering enough data demographic data for state universities as it is crucial for predicting out_of_state_total cost
# * Also, a sudden goverment policy could affect the model predictions. E.g. a sudden increase or decrease in the total price for school per year. This can distort the accuracy of the model.
# * Also,if the data is not updated,it might be difficult to have an accurate prediciton for the next year.
# * Inflation fluctuations

# %% [markdown]
# ### 4. Name and explain two accuracy metrics for regression other than MSE or RMSE. Are any of them better suited for evaluating your models, given the goal you have formulated earlier?
#
# * **Mean Absolute Error(MAE)**: which is linear in nature, matches the units of the error score and the units of the target value that is being predicted. MAE score is calculated as the average of the absolute error values.
#
# * **R-squared**: It is calculated by dividing the sum of squares of residuals from the regression model by the total sum of squares of errors from the average model and then subtract it from 1.
#
#
#
# The **Adjusted R-squared** which is a modified form of R-squared would also be suitable for evaluating the performance of the model. This is because the value of Adjusted R-squared increases if new predictors tend to improve models performance and decreases if new predictors does not improve performance as expected.

# %% [markdown]
# ### 5. What has to change in real life to completely invalidate the results you get and accuracy of your model? I.e., what laws, natural events, societal changes have to happen to make conclusions based on this dataset inadmissible for further decision-making?

# %% [markdown]
# * In a situation such as the COVID-19 pandemic, due to travel restrictions, the number of students who are enrolled into the university would be skewed.
# * A sudden goverment policy that perhaps makes coming into the country or state more difficult could affect the model.
# * Sudden rise in the inflation rate in the US

# %% [markdown]
# ## Problem 11: Classification
#
# ### Categorize the target variable (out_of_state_total) into five categories and build a classification model for the above pre-processed data.

# %% [markdown]
# Now, we apply the "pd.qcut function" to divide up the underlying data into equal sized bins. If we were to manually input the data, the distribution would change everytime. Hence, we use the function to define the bins using the quintiles method dividing every feature on groups that contain 20 % of the samples. We divide each of the new variables into quotas of "5" .

# %%
pd.qcut(univ_data['out_of_state_total'], q=5,precision = 0)
# Out:
# 0      (12236.0, 18575.0]
# 1      (18575.0, 36444.0]
# 2      (36444.0, 54748.0]
# 3      (18575.0, 36444.0]
# 4      (12236.0, 18575.0]
#               ...
# 420    (12236.0, 18575.0]
# 421     (3459.0, 12236.0]
# 422    (12236.0, 18575.0]
# 423    (54748.0, 74001.0]
# 424    (12236.0, 18575.0]
# Name: out_of_state_total, Length: 425, dtype: category
# Categories (5, interval[float64]): [(3459.0, 12236.0] < (12236.0, 18575.0] < (18575.0, 36444.0] < (36444.0, 54748.0] < (54748.0, 74001.0]]

# %% [markdown]
# We have sucessfully created five categories based on the out_of_state_total variable. Now we would assign category names to each range.
#
#
# * **Bronze**: less than 12,236 dollars
# * **Silver**: Between 12,236 and 18575 dollars
# * **Gold**: Between 18,575 and 36,444 dollars
# * **Platinum**: Between 36,444 and 54,748 dollars
# * **Gold**: Between 54,748 and 74,001 dollars

# %%
# Represent new categories with integers

univ_data['out_of_state_total'] = pd.qcut(univ_data['out_of_state_total'],
                            q=[0, .2, .4, .6, .8, 1],
                            labels=False,
                            precision=0)
univ_data.head()
# Out:
#                            name  total_enrollment      state  n_native  \
# 0               Academy College               127  Minnesota         1
# 1        Adams State University              3154   Colorado        37
# 2            Adelphi University              7610   New York        10
# 3  Adirondack Community College              4247   New York        18
# 4        Aims Community College              5001   Colorado        33
#
#    n_asian  n_black  n_hispanic  n_pacific  n_nonresident  n_total_minority  \
# 0       10       14           6          3              0                35
# 1       37      191         812         10              0              1213
# 2      554      857        1007          6            436              2587
# 3       38      126         135          2              9               395
# 4       63       78        1631          9              4              1911
#
#    ...  early_career_pay  mid_career_pay  make_world_better_percent  \
# ...

# %%
# First we update the train and test splits to for target variable.

# Split the dataset into train and test sets with stratification on the degree length
train, test = train_test_split(univ_data, test_size=0.3, random_state=1, stratify=univ_data['degree_length'])

print(train.shape, test.shape)

y_train = train.out_of_state_total

y_test = test.out_of_state_total

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (297, 32) (128, 32)
# (297, 37) (128, 37) (297,) (128,)

# %% [markdown]
# ### 1. Train the following classification models on the training set for classification and evaluate the models on the test set: SVM, k-NN, and Random Forest.

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Evaluate Model

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("ACCURACY OF THE MODEL: ",metrics.accuracy_score(y_test, y_pred))


# Creating  a confusion matrix,which compares the y_test and y_pred
from sklearn.metrics import classification_report, confusion_matrix
sv = confusion_matrix(y_test, y_pred)

from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.8515625
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84        26
#            1       0.83      0.70      0.76        27
#            2       0.83      0.83      0.83        24
#            3       0.92      0.82      0.87        28
#            4       0.92      1.00      0.96        23
#
#     accuracy                           0.85       128
#    macro avg       0.85      0.86      0.85       128
# weighted avg       0.85      0.85      0.85       128

# %%
# KNN

from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)


# Model Accuracy: how often is the classifier correct?
print("ACCURACY OF THE MODEL: ",metrics.accuracy_score(y_test, y_pred))

# Creating  a confusion matrix,which compares the y_test and y_pred
kn = confusion_matrix(y_test, y_pred)

from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.7109375
#               precision    recall  f1-score   support
#
#            0       0.56      0.77      0.65        26
#            1       0.62      0.56      0.59        27
#            2       0.82      0.58      0.68        24
#            3       0.80      0.71      0.75        28
#            4       0.85      0.96      0.90        23
#
#     accuracy                           0.71       128
#    macro avg       0.73      0.72      0.71       128
# weighted avg       0.73      0.71      0.71       128

# %%
# Random Forest

# importing random forest classifier from assemble module
from sklearn.ensemble import RandomForestClassifier


# creating a RF classifier
clf = RandomForestClassifier(n_estimators = 100) 
 
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
clf.fit(X_train, y_train)
 
# performing predictions on the test dataset
y_pred = clf.predict(X_test)


# using metrics module for accuracy calculation
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))

# Creating  a confusion matrix,which compares the y_test and y_pred
rf = confusion_matrix(y_test, y_pred)

from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.8359375
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82        26
#            1       0.78      0.67      0.72        27
#            2       0.84      0.88      0.86        24
#            3       0.96      0.79      0.86        28
#            4       0.85      1.00      0.92        23
#
#     accuracy                           0.84       128
#    macro avg       0.84      0.84      0.84       128
# weighted avg       0.84      0.84      0.83       128

# %% [markdown]
# ### 2. Create a confusion matrix for each model. Interpret the results and compare them with each other.
#
# For interpretation of the confusion matrix, we would be using the normalized correlaion matrix.This is more appropriate because of possible imbalance in classes. Not all classes have the same number of total samples, and thus the unnormalized matrix outputs the absolute value, without considering how much proportion of the total class size is predicted correctly, which leads to improper conclusions due to the colorization of the heatmap.

# %% [markdown]
# #### Using the SVM classifier

# %%
# Creating a dataframe for a array-formatted Confusion matrix,so it will be easy for plotting.
sv_svm = pd.DataFrame(sv,
                     index = ['Bronze', 'Silver', 'Gold', 'Platinum', 'Diamond'], 
                     columns = ['Bronze', 'Silver', 'Gold', 'Platinum', 'Diamond'])

#Plotting the confusion matrix
plt.figure(figsize=(5,4))
sns.heatmap(sv_svm, annot=True)
plt.title('Unnormalized Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()


#Normalized confusion matrix

#Divide each row element by the sum of the entire row
sv_svm_normalized = sv_svm.astype('float') / sv_svm.sum(axis=1)[:, np.newaxis]

fig, ax = plt.subplots(figsize=(6,4))
sns.heatmap(sv_svm_normalized, annot=True, linewidths = 0.01, ax = ax)
ax.set_title('Normalized confusion matrix')
ax.set_xlabel('PREDICTED VALUES')
ax.set_ylabel('ACTUAL VALUES')

plt.show()

# %% [markdown]
# #### Interpretation of confusion matrix SVM
#
# Glancing at the unnormalized matrix, we come to know that:
#
# * The diagonal elements represent the total correct values predicted per class. Eg: 24 values have been correctly predicted as belonging to the Bronze class.
#
#
# * The lighter the color, the greater the number. As we can see from the color-bar on the side. So naturally we would assume that — lighter colours on the diagonal elements and darker on all others mean our model is performing well and vice-versa. (However, this is not true, as we shall see from the normalized matrix.)
#
#
# * The lighter colour for diagonal element for the Platinumand Diamond classes suggest our model performs really well on  those classes.
#
#
# * Silver and Gold classes perform the worst.
#
#
# **Now let us interpret the normalized matrix**:
#
#
# * Our assumption that Bronze class was the best classified class has changed. It is now the second best class. Of all the true labels for Bronze class, our model could classify 92% of them correctly.
#
#
# * Diamond class is perfectly classified since its value is 1.
#
#
# * Gold class, which was performing one of the worst according to our un-normalized confusion matrix, now shows us that it performs good since our of all true labels for Gold class, it classifies 83% correctly. Also, Platinum class which was assumed to have performed as good as the Diamond class actually performs worst.
#
#
# * Silver class still perform the the worst.
#
#
#
#
# In summary, our model performs well for Diamond and Bronze classes, moderately for Gold and Platinum classes and badly for Silver class.

# %% [markdown]
# #### Using KNN classifier

# %%
# confusion matrix for kNN.
kn_knn = pd.DataFrame(kn,
                     index = ['Bronze', 'Silver', 'Gold', 'Platinum', 'Diamond'], 
                     columns = ['Bronze', 'Silver', 'Gold', 'Platinum', 'Diamond'])

#Plotting the confusion matrix
plt.figure(figsize=(5,4))
sns.heatmap(kn_knn, annot=True)
plt.title('Unnormalized Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

#Normalized confusion matrix

#Divide each row element by the sum of the entire row
kn_knn_normalized = kn_knn.astype('float') / kn_knn.sum(axis=1)[:, np.newaxis]

fig, ax = plt.subplots(figsize=(6,4))
sns.heatmap(kn_knn_normalized, annot=True, linewidths = 0.01, ax = ax)
ax.set_title('Normalized confusion matrix')
ax.set_xlabel('PREDICTED VALUES')
ax.set_ylabel('ACTUAL VALUES')

plt.show()

# %% [markdown]
# #### Interpretation using normalized matrix for KNN
#
#
# * Diamond class is the best classified with a value of 0.96. However, this is slighly lower when compared to the SVM classfier which perfectly classified all values in this class.
#
#
# * Bronze and Platinum classes perform moderately good with correctly predicting 77% and 71% of the samples respectively. However, this is significantly less accurate when compared to the SVM classfier which classified 92% of samples in Bronze class and 82% of samples in Platinum class.
#
#
# * Gold and Silver classes perform the the worst.

# %% [markdown]
# #### Using Random Forest Classifier

# %%
# Confuson matrix for random forest 
rf_random = pd.DataFrame(rf,
                     index = ['Bronze', 'Silver', 'Gold', 'Platinum', 'Diamond'], 
                     columns = ['Bronze', 'Silver', 'Gold', 'Platinum', 'Diamond'])

#Plotting the confusion matrix
plt.figure(figsize=(5,4))
sns.heatmap(rf_random, annot=True)
plt.title('Unnormalized Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

#Normalized confusion matrix

#Divide each row element by the sum of the entire row
rf_random_normalized = rf_random.astype('float') / rf_random.sum(axis=1)[:, np.newaxis]

fig, ax = plt.subplots(figsize=(6,4))
sns.heatmap(rf_random_normalized, annot=True, linewidths = 0.01, ax = ax)
ax.set_title('Normalized confusion matrix')
ax.set_xlabel('PREDICTED VALUES')
ax.set_ylabel('ACTUAL VALUES')

plt.show()

# %% [markdown]
# #### Interpretation using normalized matrix for Random Forest
#
#
# * Diamond class is perfectly classified since its value is 1 which is te same as the SVM classfier.
#
#
# * Bronze and Gold classes perform well with correctly predicting 88% and 83% of the samples respectively. However, the accurracy when compared to the SVM classfier for Bronze class is slightly lower with SVM classifying 92% of samples in Bronze class.
#
# * 79% of Platinum are correctly predicted.
#
# * Silver class performs the the worst when compared to other classes.

# %% [markdown]
# ### 3. Which model performs best based on which evaluation method?

# %% [markdown]
# Based on the F1-score, the best performing model is the **SVM classifier** with an **F1-score of 0.85**.

# %% [markdown]
# ### 4. Explain the evaluation method you used.
#
# The **F1 Score** is the **2 x ((precision x recall)/(precision+recall))**. The F1 score conveys the **balance** between the precision and the recall.
#
# **Precision** gives the number of positive predictions divided by the total number of positive class values predicted. It measures exactness.
#
# **Recall** gives the number of positive predictions divided by the number of positive class values in the test data. It measures completeness.

# %% [markdown]
# ### 5. For which applications would classification into these artificial categories be more useful than regression? Name at least two.

# %% [markdown]
# * When a student desires to know the categories of universities based on their out_of_total-cost. For example, if Arkansas Tech University ranks in the Bronze category based on our analysis, then it would be a good choice items of cheap out_of_state_total cost.
#
#
#
# * If the business goal is to predict the ranking of universities based on the out_of_total_cost.

# %% [markdown]
# ### 6. For which applications would regression on original values be more useful? Name at least two.
#
# * To forecast the out_of_total cost for each universities and colleges.
#
#
#
# * To understand the impact of out_of_total cost on the number of total enrolled students. It can even be to understand the effect on a particular demographic sect. For example, the number of black people.
